# %% [markdown]
# # Feature analysis - Correlations and regressions
#
# This notebooks contains an analysis of the features computed for each candidate. We compare each feature to the votes obtained using different measures.
#
# - Input: Candidates twitter features
# - Output: Correlation results, linear regression results

# %%
# !pip install pandas pyathena numpy statsmodels sklearn scipy python-dotenv plotly SQLAlchemy pyarrow kaleido nbformat matplotlib
# Out:
# Requirement already satisfied: pandas in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (1.4.0)
# Requirement already satisfied: pyathena in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (2.4.1)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (1.22.1)
# Requirement already satisfied: statsmodels in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (0.13.1)
# Requirement already satisfied: sklearn in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (0.0)
# Requirement already satisfied: scipy in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (1.7.3)
# Requirement already satisfied: python-dotenv in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (0.19.2)
# Requirement already satisfied: plotly in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (5.5.0)
# Requirement already satisfied: SQLAlchemy in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (1.4.31)
# Requirement already satisfied: pyarrow in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (6.0.1)
# Requirement already satisfied: kaleido in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (0.2.1)
# Requirement already satisfied: nbformat in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (5.1.3)
# Requirement already satisfied: matplotlib in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (3.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: botocore>=1.5.52 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from pyathena) (1.23.41)
# Requirement already satisfied: boto3>=1.4.4 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from pyathena) (1.20.41)
# Requirement already satisfied: tenacity>=4.1.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from pyathena) (8.0.1)
# Requirement already satisfied: patsy>=0.5.2 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: scikit-learn in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from sklearn) (1.0.2)
# Requirement already satisfied: six in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from plotly) (1.16.0)
# Requirement already satisfied: ipython-genutils in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from nbformat) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from nbformat) (4.4.0)
# Requirement already satisfied: jupyter-core in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from nbformat) (4.9.1)
# Requirement already satisfied: traitlets>=4.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from nbformat) (5.1.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from matplotlib) (3.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from matplotlib) (9.0.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from matplotlib) (4.28.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from boto3>=1.4.4->pyathena) (0.10.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from boto3>=1.4.4->pyathena) (0.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from botocore>=1.5.52->pyathena) (1.26.7)
# Requirement already satisfied: attrs>=17.4.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat) (0.18.1)
# Requirement already satisfied: joblib>=0.11 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from scikit-learn->sklearn) (3.0.0)

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import logging
import os
import pyathena
import dotenv
import os
import sys
import numpy as np
import plotly.express as px
from itertools import permutations
#from scipy import stats
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
import scipy
from collections import defaultdict
import tqdm
from sklearn.preprocessing import PowerTransformer
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# from utils.mongodb import *
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/statsmodels/compat/pandas.py:65: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %%
logging.basicConfig(format='[%(asctime)s] - %(name)s - %(funcName)s - %(levelname)s : %(message)s', level=logging.INFO)
log = logging.getLogger(__name__)

dotenv.load_dotenv(os.path.join(module_path, '.env'))

conn = pyathena.connect(s3_staging_dir=os.environ["AWS_ATHENA_S3_STAGING_DIR"], 
        region_name=os.environ["AWS_REGION"])

query = """
SELECT * FROM "twitter-constituyente"."constituyentes_full";
"""
candidates_df = pd.read_sql(query, conn)
candidates_df["electoral_district"] = candidates_df["electoral_district"].astype("str")
candidates_ids = candidates_df["user__id_str"].dropna().to_list()


candidates_data_df = candidates_df.dropna(subset=["user__id_str"]).set_index("user__id_str")
candidates_data_df["rm"] = candidates_data_df["electoral_district"].isin(list(map(str, range(8, 15)))).astype("int")
candidates_data_df["district_percentage"] /= 100

district_df = candidates_data_df[["electoral_district"]]
percentage_df = candidates_data_df[["district_percentage"]]
# Out:
# [2022-01-28 16:19:34,114] - botocore.credentials - load - INFO : Found credentials in environment variables.
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/io/sql.py:758: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %% [markdown]
# ## Load data

# %%
path = "/Users/jose/Library/Mobile Documents/com~apple~CloudDocs/Proyectos/Memoria/code/twitterconstituyente/processing/{}.parquet"

features_df = pd.read_parquet(path.format("final_features"))
features_agg_df = pd.read_parquet(path.format("final_features_list_agg"))
features_first16_df = pd.read_parquet(path.format("final_features_first16weeks"))
features_last2_df = pd.read_parquet(path.format("final_features_last2weeks"))

# %%
features_types_df = pd.read_csv("features_types.csv")

all_cols = features_types_df["feature"].to_list()

# %%
def normalize_by_activity(df, normalize_cols, activity_col="tweets_made"):  
  for col in normalize_cols:
      if (col != activity_col) and col in df.columns:
        df[col] /= df[activity_col]
        # if division by zero
        df[col].replace([np.inf, -np.inf], 0, inplace=True)


def get_base_votes(df, perc_df=percentage_df, index="user__id_str"):
  base_df = df.set_index(index)[all_cols]
  base_df = base_df[base_df["tweets_made"]>base_df["retweets_made"]]

  normalize_by_activity(base_df, features_types_df[
    features_types_df["type"]!="Network feature"]["feature"].to_list())

  return base_df.join(perc_df)

base_votes_df = get_base_votes(features_df)
base_votes_df.head()
# Out:
#                      out_degree       degree    in_degree  \
# user__id_str
# 100366067            128.666667   170.333333    41.666667
# 1004762296932069377  110.833333   316.555556   205.722222
# 1004858015017783302   13.222222    43.055556    29.833333
# 1007614099            16.777778    19.000000     2.222222
# 101614836            151.833333  3750.777778  3598.944444
#
#                      eigenvector_centrality  pagerank  harmonic_centrality  \
# user__id_str
# 100366067                          0.007319  0.000122         31991.366673
# 1004762296932069377                0.013303  0.001414         65512.586440
# 1004858015017783302                0.012676  0.000065         25144.905673
# 1007614099                         0.000076  0.000035          3859.242295
# 101614836                          0.056503  0.008407         78382.970894
#
#                      tweets_made  retweet_count  favorite_count  \
# user__id_str
# 100366067              32.555556       0.324232        0.459044
# 1004762296932069377    75.500000       1.041943        1.427520
# 1004858015017783302     4.055556       1.136986        4.287671
# 1007614099              3.888889       0.071429        0.142857
# 101614836              44.944444      28.030902       95.969098
#
#                      user_mentions  ...  replies_made  quotes_made    videos  \
# user__id_str                        ...
# 100366067                 0.406143  ...      0.087031     0.151877  0.001706
# 1004762296932069377       1.394408  ...      0.524650     0.074319  0.029433
# 1004858015017783302       0.397260  ...      0.109589     0.082192  0.000000
# 1007614099                0.042857  ...      0.028571     0.000000  0.000000
# 101614836                 0.222497  ...      0.097651     0.086527  0.018541
#
#                      hashtags       pos       neg   sadness     anger  \
# user__id_str
# 100366067            0.943686  0.054608  0.095563  0.018771  0.023891
# 1004762296932069377  0.144960  0.060338  0.286240  0.017660  0.124356
# 1004858015017783302  0.136986  0.191781  0.000000  0.000000  0.000000
# 1007614099           0.271429  0.014286  0.014286  0.000000  0.000000
# 101614836            0.055624  0.095179  0.100124  0.013597  0.024722
#
#                           joy  district_percentage
# user__id_str
# 100366067            0.046075               0.0480
# 1004762296932069377  0.043414               0.0552
# 1004858015017783302  0.095890               0.0241
# 1007614099           0.000000               0.0072
# 101614836            0.049444               0.0278
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Correlation between features

# %%
fig = px.imshow(
    np.abs(base_votes_df[base_votes_df.columns[:-1]].corr(method="spearman")), 
    title="Spearman correlation between Twitter influence features",
    width=800, height=800)
fig.update_layout(
    xaxis = dict(tickmode='linear', tickangle=-45),
    yaxis = dict(tickmode='linear')
)
fig.write_image("spearman_corr.pdf")
fig

# %%
px.scatter_matrix(base_votes_df[["degree", "pagerank", "harmonic_centrality"]], width=800, height=800)

# %% [markdown]
# ## Base vote analysis

# %% [markdown]
# ### Correlation

# %%
def normalize_df_by_district(norm_df, col, drop=True):
  if "electoral_district" not in norm_df.columns:
    # raise Exception("Must have district col")
    norm_df = norm_df.join(district_df)
  norm_df[col] /= norm_df.groupby('electoral_district')[col].transform('sum')
  if drop:
    return norm_df.drop(columns=["electoral_district"])
  return norm_df

def custom_log(df, col):
  df[col] = np.log(df[col] + 1)
  return df

def get_vote_correlation_df(df):
  data = []

  base_columns = [col for col in df.columns if col not in ["district_percentage", "electoral_district"]]
  transformations = {
    #"log": lambda df, col: np.log(df+1),
    "log": custom_log,
    "district_normalize": normalize_df_by_district
  }.items()
  for col in tqdm.tqdm(base_columns):
    for i in range(0, len(transformations) + 1):
      for perm in permutations(transformations, i):
        d = df.copy()
        # try:
        for name, step in perm:
          d = step(d, col=col)
        spearman, pspearman = scipy.stats.spearmanr(d[col], d["district_percentage"])
        pearson, ppearson = scipy.stats.pearsonr(d[col], d["district_percentage"])
        data.append({
            "permutation": ', '.join([name for name, step in perm]),
            "column": col,
            "spearman": spearman,
            "spearman_pvalue": pspearman,
            "pearson": pearson,
            "pearson_pvalue": ppearson
        })
        # except Exception as e:
        #   log.error(e)
        #   data.append({
        #       "permutation": ', '.join([name for name, step in perm]),
        #       "column": col,
        #       "error": True
        #   })
    
  df = pd.DataFrame(data)
  df["permutation"] = df["permutation"].apply(lambda u: "raw" if u == "" else u)
  df = df[df["permutation"].isin(["raw", "district_normalize", "log, district_normalize"])]
  df = df.merge(features_types_df, left_on="column", right_on="feature", how="left")
  return df

# %%
base_corr_df = get_vote_correlation_df(base_votes_df)
base_corr_df.head()
# Out:
# 100%|██████████| 21/21 [00:00<00:00, 146.32it/s]
#                permutation      column  spearman  spearman_pvalue   pearson  \
# 0                      raw  out_degree  0.183127     4.274982e-07  0.068135
# 1       district_normalize  out_degree  0.334836     3.703956e-21  0.133840
# 2  log, district_normalize  out_degree  0.421911     8.158362e-34  0.280721
# 3                      raw      degree  0.242342     1.636519e-11  0.270721
# 4       district_normalize      degree  0.477451     4.450092e-44  0.314174
#
#    pearson_pvalue     feature             type
# 0    6.183168e-02  out_degree  Network feature
# 1    2.325934e-04  out_degree  Network feature
# 2    4.380077e-15  out_degree  Network feature
# 3    4.252760e-14      degree  Network feature
# 4    1.089140e-18      degree  Network feature

# %% [markdown]
# #### Spearman

# %%
for group, df in base_corr_df.groupby("type"):
  px.bar(df.sort_values("spearman", ascending=False), 
    x="column", y="spearman", color="permutation", 
    barmode="group", title=f"Spearman correlation between candidates percentage<br>of votes and {group}s", labels={"column": "Feature", "spearman":"Spearman", "permutation":"Pre-processing"}).show()

# %% [markdown]
# #### Pearson

# %%
for group, df in base_corr_df.groupby("type"):
  px.bar(df.sort_values("pearson", ascending=False), 
    x="column", y="pearson", color="permutation", 
    barmode="group", title=f"Pearson correlation between candidates percentage<br>of votes and {group}s", 
    labels={"column": "Feature", "pearson":"Pearson", "permutation":"Pre-processing"}).show()

# %%
plot_df = base_corr_df[base_corr_df["permutation"]=="log, district_normalize"].sort_values("spearman")

positions = defaultdict(lambda: 'top left')
positions.update({
    "tweets_made": "top right",
    "photos": "top right",
    "eigenvector_centrality": "middle left",
    "quotes_made": "middle left"
})

plot_df["position"] = plot_df["column"].map(positions)
fig = px.scatter(plot_df,"spearman", "pearson", text="column", width=1000, height=1000)
fig.update_traces(textposition=plot_df["position"])
fig.write_image("spearman_pearson_cols.pdf")
fig

# %% [markdown]
# ### Regression

# %%
def col_to_dummy(df, col):
  df = pd.concat([df, pd.get_dummies(df[col])], axis=1)
  return df.drop(columns=[col])

ops = ["raw", "log", "dn", "logdn", "dnlog", "logdnlog" ,"dnpt", "logdnpt"]

pt = PowerTransformer(method="yeo-johnson")

def preprocess_feature(df, col, prep) -> pd.Series:
  if prep == "raw": 
    return df[col]
  if prep == "log": 
    return  np.log(df[col] + 1)
  if prep == "dn": 
    return normalize_df_by_district(df.copy(), col)[col]
  if prep == "dnpt": 
    return pd.Series(pt.fit_transform(
      normalize_df_by_district(df.copy(), col)[[col]]
    ).flatten())
  if prep == "logdn":
    df[col] = np.log(df[col] + 1)
    return normalize_df_by_district(df.copy(), col)[col]
  if prep == "logdnpt":
    df[col] = np.log(df[col] + 1)
    df[col] = normalize_df_by_district(df.copy(), col)[col]
    return pd.Series(pt.fit_transform(df[[col]]).flatten())
  if prep == "logdnlog": 
    df[col] = np.log(df[col] + 1)
    df[col] = normalize_df_by_district(df.copy(), col)[col]
    return np.log(df[col]+1)
  if prep == "dnlog": 
    return np.log(normalize_df_by_district(df.copy(), col)[col]+1)


scaler = StandardScaler()

def get_vote_regression_df(df, reg_type, col, y, interaction=None, scaling=True):
  if scaling:
    df[col] = pd.Series(scaler.fit_transform(df[[col]]).flatten())
  if interaction:
    df[f"{col}*{interaction}"] = df[col] * df[interaction]

  X2 = sm.add_constant(df)
  est = sm.OLS(y, X2)
  est2 = est.fit()
  return {
    "col": col,
    "features": df.columns.to_list(),
    "model": est2,
    "pvalues": est2.pvalues,
    "params": est2.params,
    "errors": est2.bse,
    "r2": est2.rsquared,
    "type": reg_type,
    "interaction": interaction,
  }
 # single, base, base2, interaction (rm, gender, ind)

# univariada (single)
# con variables de control
# con otras variables de control
# con interaccion con rm, gender e IND

# %%
base_notwitter_features = candidates_data_df[["list_number", "party_clean", "gender", "rm", "electoral_district", "coalicion"]]

# en promedio, a mayor cantidad de candidatos menor porcentaje
candidates_count_district = candidates_df["electoral_district"].value_counts().to_dict()
base_notwitter_features["n_candidates"] = base_notwitter_features["electoral_district"].map(candidates_count_district)
scaler = StandardScaler()
base_notwitter_features[["n_candidates"]] = scaler.fit_transform(base_notwitter_features[["n_candidates"]])

base_notwitter_features["gender"] = (base_notwitter_features["gender"]=="M").astype("int")

base_notwitter_features["list_number"] = base_notwitter_features["list_number"].astype("str")

for col in ["list_number", "party_clean", "coalicion"]:
  base_notwitter_features = col_to_dummy(base_notwitter_features, col)

base_notwitter_features["<=2"] = base_notwitter_features["1"] + base_notwitter_features["2"]


base_1_cols = [
  "gender", "rm", "n_candidates",
  "1", "2", "3", "4",
  "CIUDADANOS", "COMUNES", "CONVER.", "EVOPOLI",
  "FREVS", "IGUALDAD", "PCC", "PCCH", "PDC", "PEV",
  "PH", "PL", "PNC", "PPD", "PR", "PRO", "PS", 
  "PTR", "RD", "REPUBL.", "RN", "UDI", "UPA"
]

base_2_cols = [
  "rm", "n_candidates", "<=2",
  "Apruebo Dignidad",
  "Independientes No Neutrales",
  "Lista del Apruebo",
  "Lista del Pueblo",
  "Vamos por Chile"
]
# Out:
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/3221927005.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/3221927005.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/3221927005.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/3221927005.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# #### Regression input construction

# %%
input_regression_df = base_votes_df.join(base_notwitter_features[list(set(base_1_cols+base_2_cols))]).join(district_df).reset_index()
y = np.log(input_regression_df["district_percentage"])

# all preprocessing
def preprocess_columns(df, cols):
    for col in cols:
        df[f"{col}__raw"] = df[col]
        df[f"{col}__log"] = np.log(df[col] + 1)
        df[f"{col}__dn"] = normalize_df_by_district(df.copy(), col)[col]
        df[f"{col}__dnpt"] = pd.Series(pt.fit_transform(df[[f"{col}__dn"]]).flatten())
        df[f"{col}__logdn"] = normalize_df_by_district(df.copy(), f"{col}__log")[f"{col}__log"]
        df[f"{col}__logdnpt"] = pd.Series(pt.fit_transform(df[[f"{col}__logdn"]]).flatten())
        df[f"{col}__dnlog"] = np.log(df[f"{col}__dn"]+1)
        df[f"{col}__logdnlog"] =  np.log(df[f"{col}__logdn"]+1)

preprocess_columns(input_regression_df, all_cols)

# %% [markdown]
# #### Run different models

# %%
def run_regressions(df, preps=ops, interactions=(None, "rm", "gender"), custom_base_cols=None, y=y, cols=all_cols):
    regression_results = []

    for prep in tqdm.tqdm(preps):
        for interaction in interactions:
            for col in cols:
                col = f"{col}__{prep}"
                try:
                    if interaction is None:
                        regression_results.append(get_vote_regression_df(df[[col]], 
                        "single", col, y=y, interaction=interaction))
                    if (interaction is None) or (interaction in base_1_cols): 
                        regression_results.append(get_vote_regression_df(df[base_1_cols + [col]], 
                        "base_1", col, y=y, interaction=interaction))
                    if (interaction is None) or (interaction in base_2_cols):
                        regression_results.append(get_vote_regression_df(df[base_2_cols + [col]], 
                        "base_2", col, y=y, interaction=interaction))
                    if (custom_base_cols is not None) and (interaction in custom_base_cols):
                        regression_results.append(get_vote_regression_df(df[custom_base_cols + [col]], 
                        "custom_base", col, y=y, interaction=interaction))
                except Exception as e:
                    log.info(prep)
                    log.info(interaction)
                    log.info(col)
                    raise e

    
    base_results = {
        "base_1": get_vote_regression_df(df[base_1_cols], "base_1", None, y=y, scaling=False),
        "base_2": get_vote_regression_df(df[base_2_cols], "base_2", None, y=y, scaling=False)
    }

    for result in regression_results:
        result["pvalue_col"] = result["pvalues"].loc[result["col"]]
        result["param_col"] = result["params"].loc[result["col"]]
        result["se_col"] = result["errors"].loc[result["col"]]
        result["conf95_col"] = result["se_col"]*1.96
        result["prep"] = result["col"].split("__")[-1]
        result["clean_col"] = result["col"].split("__")[0]
        if result["interaction"]:
            result["param_interaction"] = result["params"].loc[f"{result['col']}*{result['interaction']}"]
            result["pvalue_interaction"] = result["pvalues"].loc[f"{result['col']}*{result['interaction']}"]
            result["se_interaction"] = result["errors"].loc[f"{result['col']}*{result['interaction']}"]
            result["conf95_interaction"] = result["se_interaction"]*1.96
        if result["type"] in ["base_1", "base_2"]:
            result["delta_r2"] = result["r2"] - base_results[result["type"]]["r2"]
    return pd.DataFrame(regression_results)
 
reg_results_df = run_regressions(input_regression_df)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]/var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_96875/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 100%|██████████| 8/8 [00:46<00:00,  5.87s/it]

# %% [markdown]
# #### Weights

# %%
weights_multivariate_df = reg_results_df[
    (reg_results_df["interaction"].isnull()) 
    & (reg_results_df["prep"]=="logdnpt")
    & (reg_results_df["type"]=="base_1")
].sort_values("param_col", ascending=False)
fig = px.bar(weights_multivariate_df, "clean_col", "param_col", hover_data=["clean_col", "col", "pvalue_col"], 
    error_y="conf95_col", labels={"param_col": "Regression coefficient", "clean_col": "Feature"},
    title="Linear multivariate regression weights for Twitter features")
fig.update_xaxes(tickangle=-45)
fig

# %%
weights_multivariate_df.iloc[0]["model"].summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     district_percentage   R-squared:                       0.582
# Model:                             OLS   Adj. R-squared:                  0.564
# Method:                  Least Squares   F-statistic:                     32.32
# Date:                 Mon, 24 Jan 2022   Prob (F-statistic):          9.10e-115
# Time:                         12:09:30   Log-Likelihood:                -735.65
# No. Observations:                  752   AIC:                             1535.
# Df Residuals:                      720   BIC:                             1683.
# Df Model:                           31
# Covariance Type:             nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -4.3518      0.069    -63.195      0.000      -4.487      -4.217
# gender                     -0.0365      0.078     -0.470      0.639      -0.189       0.116
# rm                         -0.1289      0.055     -2.360      0.019      -0.236      -0.022
# n_candidates               -0.1839      0.028     -6.462      0.000      -0.240      -0.128
# 1                           0.8017      0.078     10.247      0.000       0.648       0.955
# 2                           0.4488      0.083      5.436      0.000       0.287       0.611
# 3                           0.3006      0.085      3.555      0.000       0.135       0.467
# 4                           0.0104      0.089      0.117      0.907      -0.165       0.186
# CIUDADANOS                 -0.2968      0.334     -0.890      0.374      -0.952       0.358
# COMUNES                    -0.1352      0.172     -0.787      0.432      -0.473       0.202
# CONVER.                     0.4875      0.191      2.553      0.011       0.113       0.862
# EVOPOLI                     0.1475      0.127      1.166      0.244      -0.101       0.396
# FREVS                      -0.0473      0.157     -0.300      0.764      -0.356       0.262
# IGUALDAD                   -0.1532      0.175     -0.875      0.382      -0.497       0.190
# PCC                        -0.6298      0.238     -2.642      0.008      -1.098      -0.162
# PCCH                        0.2581      0.136      1.904      0.057      -0.008       0.524
# PDC                         0.1614      0.127      1.271      0.204      -0.088       0.411
# PEV                        -0.3561      0.108     -3.307      0.001      -0.567      -0.145
# PH                         -0.3441      0.340     -1.013      0.311      -1.011       0.323
# PL                         -0.0443      0.182     -0.244      0.808      -0.401       0.313
# PNC                        -0.6307      0.470     -1.342      0.180      -1.553       0.292
# PPD                         0.1679      0.157      1.067      0.286      -0.141       0.477
# PR                         -0.1994      0.196     -1.018      0.309      -0.584       0.185
# PRO                        -0.5475      0.223     -2.451      0.014      -0.986      -0.109
# PS                          0.3099      0.122      2.533      0.012       0.070       0.550
# PTR                        -1.3219      0.123    -10.731      0.000      -1.564      -1.080
# RD                          0.1388      0.133      1.047      0.296      -0.122       0.399
# REPUBL.                    -0.1111      0.228     -0.487      0.626      -0.559       0.337
# RN                          0.3985      0.105      3.790      0.000       0.192       0.605
# UDI                         0.3301      0.115      2.869      0.004       0.104       0.556
# UPA                        -1.6780      0.223     -7.516      0.000      -2.116      -1.240
# favorite_count__logdnpt     0.3378      0.029     11.539      0.000       0.280       0.395
# ==============================================================================
# Omnibus:                        4.004   Durbin-Watson:                   2.020
# Prob(Omnibus):                  0.135   Jarque-Bera (JB):                3.845
# Skew:                           0.168   Prob(JB):                        0.146
# Kurtosis:                       3.100   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
weights_univariate_df = reg_results_df[
    (reg_results_df["interaction"].isnull()) 
    & (reg_results_df["prep"]=="logdnpt")
    & (reg_results_df["type"]=="single")
].sort_values("param_col", ascending=False)
fig = px.bar(weights_univariate_df, "clean_col", "param_col", hover_data=["clean_col", "col", "pvalue_col"], 
    error_y="conf95_col", labels={"param_col": "Regression coefficient", "clean_col": "Feature"},
    title="Linear univariate regression weights for Twitter features", color="prep")
fig.update_xaxes(tickangle=-45)
fig

# %%
weights_univariate_df.iloc[0]["model"].summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     district_percentage   R-squared:                       0.297
# Model:                             OLS   Adj. R-squared:                  0.296
# Method:                  Least Squares   F-statistic:                     316.9
# Date:                 Mon, 24 Jan 2022   Prob (F-statistic):           2.15e-59
# Time:                         12:10:36   Log-Likelihood:                -930.97
# No. Observations:                  752   AIC:                             1866.
# Df Residuals:                      750   BIC:                             1875.
# Df Model:                            1
# Covariance Type:             nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -4.1660      0.030   -136.718      0.000      -4.226      -4.106
# favorite_count__logdnpt     0.5424      0.030     17.801      0.000       0.483       0.602
# ==============================================================================
# Omnibus:                        2.382   Durbin-Watson:                   1.890
# Prob(Omnibus):                  0.304   Jarque-Bera (JB):                2.329
# Skew:                          -0.136   Prob(JB):                        0.312
# Kurtosis:                       3.007   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
merged_weights_df = weights_univariate_df.set_index("clean_col").add_suffix("__uni").join(weights_multivariate_df.set_index("clean_col").add_suffix("__multi")).reset_index()

px.scatter(merged_weights_df, 'param_col__uni', 'param_col__multi', text="clean_col", 
labels={"param_col__uni":"Univariate regression coefficient", 
"param_col__multi":"Multivariate regression coefficient"}, width=800, height=800)

# %% [markdown]
# #### R2

# %%
positions = defaultdict(lambda: 'top left')
# positions.update({
#     "tweets_made": "top right",
#     "photos": "top right",
#     "eigenvector_centrality": "middle left",
#     "quotes_made": "middle left"
# })

merged_weights_df["position"] = merged_weights_df["clean_col"].map(positions)

fig = px.scatter(merged_weights_df.reset_index(), 'r2__uni', 'delta_r2__multi', text="clean_col", 
labels={'r2__uni': 'R2 univariate regression', 'delta_r2__multi': 'Delta R2 multivariate regression'}, 
title="R2", width=800, height=800)
fig.update_traces(textposition=merged_weights_df["position"])
#fig.write_image("test.pdf")
fig

# %% [markdown]
# #### Interactions

# %%
reg_results_df[
        (reg_results_df["interaction"]=="rm") 
        & (reg_results_df["prep"]=="logdnpt")
        & (reg_results_df["type"]=="base_1")
    ].sort_values("param_interaction", ascending=False)
# Out:
#                                  col  \
# 947                  degree__logdnpt
# 949               in_degree__logdnpt
# 945              out_degree__logdnpt
# 961          favorite_count__logdnpt
# 957             tweets_made__logdnpt
# 959           retweet_count__logdnpt
# 953                pagerank__logdnpt
# 951  eigenvector_centrality__logdnpt
# 955     harmonic_centrality__logdnpt
# 967           retweets_made__logdnpt
# 971             quotes_made__logdnpt
# 969            replies_made__logdnpt
# 963           user_mentions__logdnpt
# 977                     pos__logdnpt
# 985                     joy__logdnpt
# 981                 sadness__logdnpt
# 983                   anger__logdnpt
# 979                     neg__logdnpt
# 973                  videos__logdnpt
# 975                hashtags__logdnpt
# 965                  photos__logdnpt
#
#                                               features  \
# 947  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 949  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 945  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 961  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 957  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 959  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 953  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 951  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 955  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 967  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 971  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 969  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 963  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 977  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 985  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 981  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 983  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 979  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 973  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 975  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 965  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
#
#                                                  model  \
# 947  <statsmodels.regression.linear_model.Regressio...
# 949  <statsmodels.regression.linear_model.Regressio...
# 945  <statsmodels.regression.linear_model.Regressio...
# 961  <statsmodels.regression.linear_model.Regressio...
# 957  <statsmodels.regression.linear_model.Regressio...
# 959  <statsmodels.regression.linear_model.Regressio...
# 953  <statsmodels.regression.linear_model.Regressio...
# 951  <statsmodels.regression.linear_model.Regressio...
# 955  <statsmodels.regression.linear_model.Regressio...
# 967  <statsmodels.regression.linear_model.Regressio...
# 971  <statsmodels.regression.linear_model.Regressio...
# 969  <statsmodels.regression.linear_model.Regressio...
# 963  <statsmodels.regression.linear_model.Regressio...
# 977  <statsmodels.regression.linear_model.Regressio...
# 985  <statsmodels.regression.linear_model.Regressio...
# 981  <statsmodels.regression.linear_model.Regressio...
# 983  <statsmodels.regression.linear_model.Regressio...
# 979  <statsmodels.regression.linear_model.Regressio...
# 973  <statsmodels.regression.linear_model.Regressio...
# 975  <statsmodels.regression.linear_model.Regressio...
# 965  <statsmodels.regression.linear_model.Regressio...
#
#                                                pvalues  \
# 947  const                 5.551458e-289
# gender    ...
# 949  const                    1.193786e-288
# gender ...
# 945  const                     1.140299e-281
# gender...
# 961  const                         1.114554e-296
# ge...
# 957  const                      6.534999e-283
# gende...
# 959  const                        4.238531e-292
# gen...
# 953  const                   2.116981e-293
# gender  ...
# 951  const                                 4.994094...
# 955  const                              1.414610e-2...
# 967  const                        1.823507e-277
# gen...
# 971  const                      5.442090e-278
# gende...
# 969  const                       1.899370e-276
# gend...
# 963  const                        9.400706e-276
# gen...
# 977  const              7.434091e-277
# gender       ...
# 985  const              8.632608e-278
# gender       ...
# 981  const                  1.093592e-275
# gender   ...
# 983  const                3.770321e-276
# gender     ...
# 979  const              1.886893e-276
# gender       ...
# 973  const                 2.267066e-276
# gender    ...
# 975  const                   4.483316e-276
# gender  ...
# 965  const                 1.484999e-276
# gender    ...
#
#                                                 params  \
# 947  const                -4.335626
# gender         ...
# 949  const                   -4.338884
# gender      ...
# 945  const                    -4.359197
# gender     ...
# 961  const                        -4.330462
# gender ...
# 957  const                     -4.371782
# gender    ...
# 959  const                       -4.314597
# gender  ...
# 953  const                  -4.332791
# gender       ...
# 951  const                                -4.319995...
# 955  const                             -4.375843
# ge...
# 967  const                       -4.374686
# gender  ...
# 971  const                     -4.385165
# gender    ...
# 969  const                      -4.386226
# gender   ...
# 963  const                       -4.390122
# gender  ...
# 977  const             -4.385200
# gender            ...
# 985  const             -4.379715
# gender            ...
# 981  const                 -4.380288
# gender        ...
# 983  const               -4.391150
# gender          ...
# 979  const             -4.396199
# gender            ...
# 973  const                -4.393177
# gender         ...
# 975  const                  -4.389158
# gender       ...
# 965  const                -4.397658
# gender         ...
#
#                                                 errors        r2    type  \
# 947  const                 0.070394
# gender         ...  0.565285  base_1
# 949  const                    0.070536
# gender      ...  0.563243  base_1
# 945  const                     0.072785
# gender     ...  0.534237  base_1
# 961  const                         0.068288
# gender ...  0.591673  base_1
# 957  const                      0.072648
# gender    ...  0.534810  base_1
# 959  const                        0.069227
# gender  ...  0.581113  base_1
# 953  const                   0.069177
# gender       ...  0.579852  base_1
# 951  const                                 0.070396...  0.567007  base_1
# 955  const                              0.073371
# ge...  0.525591  base_1
# 967  const                        0.074236
# gender  ...  0.514948  base_1
# 971  const                      0.074263
# gender    ...  0.513423  base_1
# 969  const                       0.074726
# gender   ...  0.510352  base_1
# 963  const                        0.074993
# gender  ...  0.508914  base_1
# 977  const              0.074591
# gender            ...  0.509239  base_1
# 985  const              0.074228
# gender            ...  0.515432  base_1
# 981  const                  0.074844
# gender        ...  0.507406  base_1
# 983  const                0.074896
# gender          ...  0.505700  base_1
# 979  const              0.074895
# gender            ...  0.506503  base_1
# 973  const                 0.074866
# gender         ...  0.505978  base_1
# 975  const                   0.074884
# gender       ...  0.506584  base_1
# 965  const                 0.074889
# gender         ...  0.507108  base_1
#
#     interaction    pvalue_col  param_col    se_col  conf95_col     prep  \
# 947          rm  3.449608e-11   0.219786  0.032654    0.064001  logdnpt
# 949          rm  1.233783e-10   0.204603  0.031327    0.061401  logdnpt
# 945          rm  4.976108e-05   0.130369  0.031942    0.062605  logdnpt
# 961          rm  2.491950e-17   0.279478  0.032172    0.063057  logdnpt
# 957          rm  5.214465e-05   0.135495  0.033288    0.065245  logdnpt
# 959          rm  6.211313e-15   0.252569  0.031688    0.062109  logdnpt
# 953          rm  1.802142e-12   0.227547  0.031713    0.062158  logdnpt
# 951          rm  1.358421e-10   0.212943  0.032680    0.064053  logdnpt
# 955          rm  1.884215e-05   0.136893  0.031783    0.062295  logdnpt
# 967          rm  8.676411e-03   0.085163  0.032360    0.063425  logdnpt
# 971          rm  2.061836e-02   0.070944  0.030579    0.059935  logdnpt
# 969          rm  7.061931e-02   0.056889  0.031420    0.061583  logdnpt
# 963          rm  1.063605e-01   0.052017  0.032173    0.063059  logdnpt
# 977          rm  6.378506e-02   0.062483  0.033656    0.065965  logdnpt
# 985          rm  8.813319e-04   0.109728  0.032854    0.064393  logdnpt
# 981          rm  9.467074e-02   0.051772  0.030937    0.060637  logdnpt
# 983          rm  2.117009e-01   0.039520  0.031616    0.061967  logdnpt
# 979          rm  8.949717e-02   0.052042  0.030607    0.059989  logdnpt
# 973          rm  1.584419e-01   0.045206  0.032020    0.062759  logdnpt
# 975          rm  5.437549e-01   0.020105  0.033097    0.064871  logdnpt
# 965          rm  3.831291e-01   0.028217  0.032334    0.063374  logdnpt
#
#                   clean_col  delta_r2  param_interaction  pvalue_interaction  \
# 947                  degree  0.060774           0.294986            0.000005
# 949               in_degree  0.058732           0.277824            0.000012
# 945              out_degree  0.029726           0.239539            0.000375
# 961          favorite_count  0.087162           0.236085            0.000036
# 957             tweets_made  0.030300           0.233999            0.000367
# 959           retweet_count  0.076602           0.213601            0.000167
# 953                pagerank  0.075341           0.201141            0.000150
# 951  eigenvector_centrality  0.062496           0.200790            0.000204
# 955     harmonic_centrality  0.021080           0.178703            0.021786
# 967           retweets_made  0.010437           0.107073            0.110576
# 971             quotes_made  0.008912           0.088627            0.160975
# 969            replies_made  0.005841           0.082765            0.200620
# 963           user_mentions  0.004403           0.076350            0.257012
# 977                     pos  0.004728           0.058678            0.360078
# 985                     joy  0.010921           0.038544            0.538519
# 981                 sadness  0.002895           0.015555            0.799652
# 983                   anger  0.001189          -0.011253            0.857111
# 979                     neg  0.001992          -0.037154            0.586585
# 973                  videos  0.001467          -0.062014            0.311689
# 975                hashtags  0.002073          -0.105315            0.086990
# 965                  photos  0.002597          -0.123709            0.052144
#
#      se_interaction  conf95_interaction
# 947        0.064086            0.125608
# 949        0.062924            0.123331
# 945        0.067020            0.131360
# 961        0.056751            0.111232
# 957        0.065363            0.128111
# 959        0.056436            0.110614
# 953        0.052761            0.103413
# 951        0.053790            0.105429
# 955        0.077728            0.152347
# 967        0.067022            0.131364
# 971        0.063158            0.123790
# 969        0.064612            0.126639
# 963        0.067305            0.131918
# 977        0.064073            0.125582
# 985        0.062638            0.122770
# 981        0.061265            0.120079
# 983        0.062474            0.122449
# 979        0.068294            0.133857
# 973        0.061254            0.120058
# 975        0.061450            0.120442
# 965        0.063598            0.124653

# %%
for interaction in ["rm", "gender"]:
    weights_interaction_df = reg_results_df[
        (reg_results_df["interaction"]==interaction) 
        & (reg_results_df["prep"]=="logdnpt")
        & (reg_results_df["type"]=="base_1")
    ].sort_values("param_interaction", ascending=False)
    fig = px.bar(weights_interaction_df, "clean_col", "param_interaction", hover_data=["clean_col", "col", "pvalue_col"], 
        error_y="conf95_interaction", labels={"param_col": "Regression coefficient", "clean_col": "Feature"},
        title=f"Regression coefficient for interaction term with {interaction}")
    fig.update_xaxes(tickangle=-45)
    fig.show()

# %%
for interaction in ["rm", "gender"]:
    weights_interaction_df = reg_results_df[
        (reg_results_df["interaction"]==interaction) 
        & (reg_results_df["prep"]=="logdnpt")
        & (reg_results_df["type"]=="base_1")
    ].sort_values("param_interaction", ascending=False)
    fig = px.bar(weights_interaction_df, "clean_col", "param_interaction", hover_data=["clean_col", "col", "pvalue_col"], 
        error_y="conf95_interaction", labels={"param_col": "Regression coefficient", "clean_col": "Feature"},
        title=f"Regression coefficient for interaction term with {interaction}")
    fig.update_xaxes(tickangle=-45)
    fig.show()

# %%
reg_results_df[
        (reg_results_df["interaction"]=="rm") 
        & (reg_results_df["prep"]=="logdnpt")
        & (reg_results_df["type"]=="base_2")
].iloc[0]["model"].summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     district_percentage   R-squared:                       0.465
# Model:                             OLS   Adj. R-squared:                  0.457
# Method:                  Least Squares   F-statistic:                     64.30
# Date:                 Mon, 24 Jan 2022   Prob (F-statistic):           1.13e-93
# Time:                         12:40:02   Log-Likelihood:                -828.57
# No. Observations:                  752   AIC:                             1679.
# Df Residuals:                      741   BIC:                             1730.
# Df Model:                           10
# Covariance Type:             nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                          -4.7758      0.061    -78.347      0.000      -4.895      -4.656
# rm                             -0.1277      0.061     -2.084      0.037      -0.248      -0.007
# n_candidates                   -0.2366      0.031     -7.639      0.000      -0.297      -0.176
# <=2                             0.6199      0.056     11.081      0.000       0.510       0.730
# Apruebo Dignidad                0.6211      0.087      7.169      0.000       0.451       0.791
# Independientes No Neutrales     0.2842      0.099      2.870      0.004       0.090       0.479
# Lista del Apruebo               0.5485      0.086      6.395      0.000       0.380       0.717
# Lista del Pueblo                0.9094      0.097      9.364      0.000       0.719       1.100
# Vamos por Chile                 0.8356      0.083     10.028      0.000       0.672       0.999
# out_degree__logdnpt             0.1755      0.033      5.349      0.000       0.111       0.240
# out_degree__logdnpt*rm          0.2316      0.070      3.314      0.001       0.094       0.369
# ==============================================================================
# Omnibus:                       15.860   Durbin-Watson:                   1.933
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               17.032
# Skew:                           0.308   Prob(JB):                     0.000200
# Kurtosis:                       3.404   Cond. No.                         6.73
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
reg_results_df[
        (reg_results_df["interaction"]=="gender") 
        & (reg_results_df["prep"]=="logdnpt")
        & (reg_results_df["type"]=="base_1")
    ].sort_values("r2", ascending=False).tail(1).iloc[0]["model"].summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     district_percentage   R-squared:                       0.505
# Model:                             OLS   Adj. R-squared:                  0.483
# Method:                  Least Squares   F-statistic:                     22.93
# Date:                 Mon, 24 Jan 2022   Prob (F-statistic):           1.35e-88
# Time:                         12:39:59   Log-Likelihood:                -799.05
# No. Observations:                  752   AIC:                             1664.
# Df Residuals:                      719   BIC:                             1817.
# Df Model:                           32
# Covariance Type:             nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       -4.3878      0.075    -58.502      0.000      -4.535      -4.241
# gender                      -0.0799      0.085     -0.943      0.346      -0.246       0.086
# rm                          -0.1877      0.059     -3.161      0.002      -0.304      -0.071
# n_candidates                -0.2897      0.031     -9.444      0.000      -0.350      -0.229
# 1                            0.8930      0.085     10.523      0.000       0.726       1.060
# 2                            0.4769      0.090      5.282      0.000       0.300       0.654
# 3                            0.2953      0.092      3.205      0.001       0.114       0.476
# 4                           -0.0041      0.097     -0.042      0.966      -0.195       0.187
# CIUDADANOS                   0.0119      0.363      0.033      0.974      -0.700       0.724
# COMUNES                      0.1237      0.186      0.667      0.505      -0.241       0.488
# CONVER.                      0.9294      0.204      4.552      0.000       0.529       1.330
# EVOPOLI                      0.3009      0.137      2.195      0.029       0.032       0.570
# FREVS                        0.0446      0.173      0.259      0.796      -0.294       0.383
# IGUALDAD                    -0.2226      0.191     -1.168      0.243      -0.597       0.152
# PCC                         -0.8202      0.260     -3.150      0.002      -1.331      -0.309
# PCCH                         0.5308      0.146      3.644      0.000       0.245       0.817
# PDC                          0.2592      0.138      1.880      0.061      -0.011       0.530
# PEV                         -0.5757      0.116     -4.971      0.000      -0.803      -0.348
# PH                          -0.6306      0.369     -1.708      0.088      -1.355       0.094
# PL                           0.1781      0.197      0.904      0.366      -0.209       0.565
# PNC                         -1.0360      0.511     -2.028      0.043      -2.039      -0.033
# PPD                          0.3691      0.170      2.168      0.030       0.035       0.703
# PR                          -0.1980      0.213     -0.929      0.353      -0.617       0.221
# PRO                         -0.5252      0.244     -2.154      0.032      -1.004      -0.047
# PS                           0.4743      0.132      3.583      0.000       0.214       0.734
# PTR                         -1.3103      0.134     -9.759      0.000      -1.574      -1.047
# RD                           0.3892      0.143      2.727      0.007       0.109       0.669
# REPUBL.                      0.3239      0.245      1.320      0.187      -0.158       0.806
# RN                           0.4765      0.114      4.170      0.000       0.252       0.701
# UDI                          0.5034      0.125      4.033      0.000       0.258       0.749
# UPA                         -1.7757      0.243     -7.307      0.000      -2.253      -1.299
# hashtags__logdnpt            0.0126      0.038      0.330      0.742      -0.063       0.088
# hashtags__logdnpt*gender    -0.0442      0.054     -0.824      0.410      -0.149       0.061
# ==============================================================================
# Omnibus:                       15.558   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.312
# Skew:                           0.266   Prob(JB):                     0.000106
# Kurtosis:                       3.549   Cond. No.                         24.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## List aggregation

# %%
candidates_data_df["list_agg"] = "D" + candidates_data_df["electoral_district"].astype("str") + "&" + candidates_data_df["list"]
list_percentage_df = candidates_data_df.groupby(["electoral_district", "list", "list_agg"])["district_percentage"].sum().reset_index().set_index("list_agg")
list_base_votes_df = get_base_votes(features_agg_df, list_percentage_df, "list")

# %% [markdown]
# ### Correlation

# %%
list_base_corr_df = get_vote_correlation_df(list_base_votes_df.drop(columns=["list"]))
list_base_corr_df.head()
# Out:
# 100%|██████████| 21/21 [00:00<00:00, 263.81it/s]
#                permutation      column  spearman  spearman_pvalue   pearson  \
# 0                      raw  out_degree  0.536130     5.976427e-17  0.313792
# 1       district_normalize  out_degree  0.596472     1.582267e-21  0.356755
# 2  log, district_normalize  out_degree  0.578932     4.244990e-20  0.476478
# 3                      raw      degree  0.576192     6.972126e-20  0.415786
# 4       district_normalize      degree  0.658167     2.533381e-27  0.463351
#
#    pearson_pvalue     feature             type
# 0    3.716627e-06  out_degree  Network feature
# 1    1.144643e-07  out_degree  Network feature
# 2    3.043316e-13  out_degree  Network feature
# 3    3.833310e-10      degree  Network feature
# 4    1.609660e-12      degree  Network feature

# %%
candidates_data_df["list_agg"].value_counts()
# Out:
# D8&YQ. APRUEBO DIGNIDAD                                               8
# D7&XP. VAMOS POR CHILE                                                8
# D10&YQ. APRUEBO DIGNIDAD                                              8
# D10&YB. LISTA DEL APRUEBO                                             8
# D6&XP. VAMOS POR CHILE                                                8
#                                                                      ..
# D22&ZK. ORGANIZACIONES SOCIALES Y TERRITORIALES DEL WALLMAPU (D22)    1
# D7&XG. PARTIDO HUMANISTA                                              1
# D6&CANDIDATURA INDEPENDIENTE                                          1
# D5&WB. INDEPENDIENTES POR LA REGION DE COQUIMBO (D5)                  1
# D1&WE. SUMATE AHORA (D1)                                              1
# Name: list_agg, Length: 210, dtype: int64

# %%
best_base_corr_df = base_corr_df[base_corr_df["permutation"]=="log, district_normalize"]
best_base_corr_df["corr_type"] = "candidate"

best_list_base_corr_df = list_base_corr_df[list_base_corr_df["permutation"]=="log, district_normalize"]
best_list_base_corr_df["corr_type"] = "agg list"

plot_df = pd.concat([best_base_corr_df, best_list_base_corr_df])
px.bar(plot_df, "column", "spearman", color="corr_type", barmode="group")
# Out:
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/946174703.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/946174703.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Regression

# %% [markdown]
# ## Last 2 weeks

# %%
base_votes_first16_df = get_base_votes(features_first16_df)
base_votes_last2_df = get_base_votes(features_last2_df)

# %% [markdown]
# ### Correlation

# %%
base_corr_first16_df = get_vote_correlation_df(base_votes_first16_df)
base_corr_last2_df = get_vote_correlation_df(base_votes_last2_df.drop(columns=["sadness"]))
# Out:
# 100%|██████████| 21/21 [00:00<00:00, 149.10it/s]
# 100%|██████████| 20/20 [00:00<00:00, 168.89it/s]

# %%
corr_dfs = {
"all": base_corr_df.copy(),
"first 16 weeks": base_corr_first16_df.copy(),
"last 2 weeks": base_corr_last2_df.copy()
}
permutation = "log, district_normalize"
for time_range, df in corr_dfs.items():
    df["time_range"] = time_range
    corr_dfs[time_range] = df[df["permutation"]==permutation]

plot_df = pd.concat(corr_dfs.values())
plot_df.head()
# Out:
#                 permutation                  column  spearman  \
# 2   log, district_normalize              out_degree  0.421911
# 5   log, district_normalize                  degree  0.517349
# 8   log, district_normalize               in_degree  0.463117
# 11  log, district_normalize  eigenvector_centrality  0.324875
# 14  log, district_normalize                pagerank  0.480441
#
#     spearman_pvalue   pearson  pearson_pvalue                 feature  \
# 2      8.158362e-34  0.280721    4.380077e-15              out_degree
# 5      1.043125e-52  0.392133    4.745370e-29                  degree
# 8      3.027170e-41  0.397101    8.211435e-30               in_degree
# 11     6.059220e-20  0.273405    2.331899e-14  eigenvector_centrality
# 14     1.097755e-44  0.323359    9.189365e-20                pagerank
#
#                type time_range
# 2   Network feature        all
# 5   Network feature        all
# 8   Network feature        all
# 11  Network feature        all
# 14  Network feature        all

# %%
px.bar(plot_df, "column", "spearman", color="time_range", barmode="group")

# %% [markdown]
# ### Regression

# %%
input_regression_first16_df = base_votes_last2_df.join(base_notwitter_features[list(set(base_1_cols+base_2_cols))]).join(district_df).reset_index()
y_first16 = np.log(input_regression_first16_df["district_percentage"])
preprocess_columns(input_regression_first16_df, all_cols)
input_regression_first16_df["last2weeks"] = 0

input_regression_last2_df = base_votes_last2_df.join(base_notwitter_features[list(set(base_1_cols+base_2_cols))]).join(district_df).reset_index()
y_last2 = np.log(input_regression_last2_df["district_percentage"])
preprocess_columns(input_regression_last2_df, all_cols)
input_regression_last2_df["last2weeks"] = 1

input_regression_temp_df = pd.concat([input_regression_first16_df, input_regression_last2_df]).reset_index(drop=True)
y = pd.concat([y_first16, y_last2]).reset_index(drop=True)

# %%
input_regression_temp_df.isnull().sum().sort_values().tail(10)
# Out:
# degree__logdnpt       0
# in_degree__dnlog      0
# degree__logdnlog      0
# in_degree__raw        0
# sadness__dnlog       94
# sadness__dnpt        94
# sadness__logdn       94
# sadness__logdnpt     94
# sadness__dn          94
# sadness__logdnlog    94
# dtype: int64

# %%
temp_base_columns = base_1_cols + ["last2weeks"]

# %%
reg_result_df = run_regressions(input_regression_temp_df, ["logdnpt"], ["last2weeks"], temp_base_columns, y=y, cols=[col for col in all_cols if col not in ["sadness"]])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]/var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vp/96_98lg94l3fyssj8jwc19bw0000gn/T/ipykernel_80414/1133956010.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 100%|██████████| 1/1 [00:25<00:00, 25.96s/it]

# %%
reg_result_df[
    (reg_result_df["interaction"]=="last2weeks") 
    & (reg_result_df["prep"]=="logdnpt")
    & (reg_result_df["type"]=="custom_base")
]
# Out:
#                                 col  \
# 0               out_degree__logdnpt
# 1                   degree__logdnpt
# 2                in_degree__logdnpt
# 3   eigenvector_centrality__logdnpt
# 4                 pagerank__logdnpt
# 5      harmonic_centrality__logdnpt
# 6              tweets_made__logdnpt
# 7            retweet_count__logdnpt
# 8           favorite_count__logdnpt
# 9            user_mentions__logdnpt
# 10                  photos__logdnpt
# 11           retweets_made__logdnpt
# 12            replies_made__logdnpt
# 13             quotes_made__logdnpt
# 14                  videos__logdnpt
# 15                hashtags__logdnpt
# 16                     pos__logdnpt
# 17                     neg__logdnpt
# 18                   anger__logdnpt
# 19                     joy__logdnpt
#
#                                              features  \
# 0   [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 1   [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 2   [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 3   [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 4   [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 5   [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 6   [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 7   [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 8   [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 9   [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 10  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 11  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 12  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 13  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 14  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 15  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 16  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 17  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 18  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
# 19  [gender, rm, n_candidates, 1, 2, 3, 4, CIUDADA...
#
#                                                 model  \
# 0   <statsmodels.regression.linear_model.Regressio...
# 1   <statsmodels.regression.linear_model.Regressio...
# 2   <statsmodels.regression.linear_model.Regressio...
# 3   <statsmodels.regression.linear_model.Regressio...
# 4   <statsmodels.regression.linear_model.Regressio...
# 5   <statsmodels.regression.linear_model.Regressio...
# 6   <statsmodels.regression.linear_model.Regressio...
# 7   <statsmodels.regression.linear_model.Regressio...
# 8   <statsmodels.regression.linear_model.Regressio...
# 9   <statsmodels.regression.linear_model.Regressio...
# 10  <statsmodels.regression.linear_model.Regressio...
# 11  <statsmodels.regression.linear_model.Regressio...
# 12  <statsmodels.regression.linear_model.Regressio...
# 13  <statsmodels.regression.linear_model.Regressio...
# 14  <statsmodels.regression.linear_model.Regressio...
# 15  <statsmodels.regression.linear_model.Regressio...
# 16  <statsmodels.regression.linear_model.Regressio...
# 17  <statsmodels.regression.linear_model.Regressio...
# 18  <statsmodels.regression.linear_model.Regressio...
# 19  <statsmodels.regression.linear_model.Regressio...
#
#                                               pvalues  \
# 0   const                             0.000000e+00...
# 1   const                         0.000000e+00
# gen...
# 2   const                            0.000000e+00
# ...
# 3   const                                         ...
# 4   const                           0.000000e+00
# g...
# 5   const                                      0.0...
# 6   const                              0.000000e+0...
# 7   const                                0.000000e...
# 8   const                                 0.000000...
# 9   const                                0.000000e...
# 10  const                         0.000000e+00
# gen...
# 11  const                                0.000000e...
# 12  const                               0.000000e+...
# 13  const                              0.000000e+0...
# 14  const                         0.000000e+00
# gen...
# 15  const                           0.000000e+00
# g...
# 16  const                      0.000000e+00
# gender...
# 17  const                      0.000000e+00
# gender...
# 18  const                        0.000000e+00
# gend...
# 19  const                      0.000000e+00
# gender...
#
#                                                params  \
# 0   const                            -4.419570e+00...
# 1   const                        -4.435345e+00
# gen...
# 2   const                           -4.423762e+00
# ...
# 3   const                                        -...
# 4   const                          -4.403989e+00
# g...
# 5   const                                     -4.4...
# 6   const                             -4.452774e+0...
# 7   const                               -4.427930e...
# 8   const                                -4.426414...
# 9   const                               -4.416915e...
# 10  const                        -4.409930e+00
# gen...
# 11  const                               -4.416271e...
# 12  const                              -4.405300e+...
# 13  const                             -4.397189e+0...
# 14  const                        -4.416648e+00
# gen...
# 15  const                          -4.403584e+00
# g...
# 16  const                     -4.383803e+00
# gender...
# 17  const                     -4.408699e+00
# gender...
# 18  const                       -4.416585e+00
# gend...
# 19  const                     -4.394067e+00
# gender...
#
#                                                errors        r2         type  \
# 0   const                             6.780063e-02...  0.489973  custom_base
# 1   const                         6.509075e-02
# gen...  0.530116  custom_base
# 2   const                            6.527990e-02
# ...  0.526892  custom_base
# 3   const                                         ...  0.519070  custom_base
# 4   const                           6.401371e-02
# g...  0.544677  custom_base
# 5   const                                      6.7...  0.498440  custom_base
# 6   const                              6.720319e-0...  0.502099  custom_base
# 7   const                                6.437242e...  0.540016  custom_base
# 8   const                                 6.371725...  0.549237  custom_base
# 9   const                                6.926197e...  0.470759  custom_base
# 10  const                         6.941589e-02
# gen...  0.468359  custom_base
# 11  const                                6.857187e...  0.478572  custom_base
# 12  const                               6.917802e-...  0.468782  custom_base
# 13  const                              6.877096e-0...  0.474624  custom_base
# 14  const                         6.923906e-02
# gen...  0.470868  custom_base
# 15  const                           6.977221e-02
# g...  0.467350  custom_base
# 16  const                      6.847821e-02
# gender...  0.480266  custom_base
# 17  const                      6.954918e-02
# gender...  0.467857  custom_base
# 18  const                        6.922845e-02
# gend...  0.470935  custom_base
# 19  const                      6.806340e-02
# gender...  0.485406  custom_base
#
#    interaction    pvalue_col  param_col    se_col  conf95_col     prep  \
# 0   last2weeks  1.373137e-07   0.179284  0.033797    0.066243  logdnpt
# 1   last2weeks  5.002434e-21   0.335044  0.034861    0.068328  logdnpt
# 2   last2weeks  2.690480e-18   0.286963  0.032299    0.063307  logdnpt
# 3   last2weeks  3.000718e-15   0.252136  0.031479    0.061698  logdnpt
# 4   last2weeks  8.106413e-23   0.308190  0.030625    0.060024  logdnpt
# 5   last2weeks  1.025543e-09   0.201423  0.032695    0.064081  logdnpt
# 6   last2weeks  3.003734e-12   0.261346  0.037018    0.072556  logdnpt
# 7   last2weeks  2.162484e-21   0.298636  0.030774    0.060316  logdnpt
# 8   last2weeks  2.361848e-25   0.336850  0.031547    0.061831  logdnpt
# 9   last2weeks  5.079077e-02   0.064056  0.032758    0.064205  logdnpt
# 10  last2weeks  2.952868e-01   0.033454  0.031949    0.062620  logdnpt
# 11  last2weeks  2.797215e-04   0.122094  0.033491    0.065643  logdnpt
# 12  last2weeks  2.113570e-01   0.040209  0.032152    0.063018  logdnpt
# 13  last2weeks  5.671502e-03   0.087226  0.031469    0.061679  logdnpt
# 14  last2weeks  5.226196e-02   0.062015  0.031915    0.062553  logdnpt
# 15  last2weeks  8.617384e-01   0.005620  0.032263    0.063235  logdnpt
# 16  last2weeks  1.438858e-04   0.123303  0.032318    0.063344  logdnpt
# 17  last2weeks  4.554177e-01   0.023677  0.031709    0.062149  logdnpt
# 18  last2weeks  5.298937e-02   0.060974  0.031476    0.061693  logdnpt
# 19  last2weeks  7.380805e-06   0.143813  0.031925    0.062573  logdnpt
#
#                  clean_col  param_interaction  pvalue_interaction  \
# 0               out_degree       2.749335e-16                 1.0
# 1                   degree      -5.493338e-16                 1.0
# 2                in_degree      -1.591239e-16                 1.0
# 3   eigenvector_centrality      -1.793209e-15                 1.0
# 4                 pagerank       1.742850e-15                 1.0
# 5      harmonic_centrality      -3.491759e-16                 1.0
# 6              tweets_made      -1.434887e-15                 1.0
# 7            retweet_count       1.263412e-15                 1.0
# 8           favorite_count       5.580320e-17                 1.0
# 9            user_mentions       5.308210e-18                 1.0
# 10                  photos       2.793365e-16                 1.0
# 11           retweets_made       2.516777e-16                 1.0
# 12            replies_made       1.129015e-15                 1.0
# 13             quotes_made      -2.603763e-15                 1.0
# 14                  videos       3.314918e-16                 1.0
# 15                hashtags       7.389312e-16                 1.0
# 16                     pos       6.773702e-16                 1.0
# 17                     neg       1.918702e-16                 1.0
# 18                   anger      -1.879881e-15                 1.0
# 19                     joy       2.891391e-17                 1.0
#
#     se_interaction  conf95_interaction
# 0         0.042961            0.084204
# 1         0.041236            0.080822
# 2         0.041377            0.081099
# 3         0.041718            0.081767
# 4         0.040592            0.079560
# 5         0.042603            0.083502
# 6         0.042447            0.083197
# 7         0.040799            0.079966
# 8         0.040388            0.079161
# 9         0.043763            0.085775
# 10        0.043862            0.085970
# 11        0.043439            0.085140
# 12        0.043845            0.085935
# 13        0.043603            0.085461
# 14        0.043758            0.085766
# 15        0.043904            0.086051
# 16        0.043368            0.085001
# 17        0.043883            0.086010
# 18        0.043756            0.085761
# 19        0.043153            0.084580

# %%
weights_interaction_df = reg_result_df[
    (reg_result_df["interaction"]=="last2weeks") 
    & (reg_result_df["prep"]=="logdnpt")
    & (reg_result_df["type"]=="custom_base")
].sort_values("param_interaction", ascending=False)
fig = px.bar(weights_interaction_df, "clean_col", "param_interaction", hover_data=["clean_col", "col", "pvalue_col"], 
    error_y="conf95_interaction", labels={"param_col": "Regression coefficient", "clean_col": "Feature"},
    title=f"Regression coefficient for interaction term with last2weeks")
fig.update_xaxes(tickangle=-45)
fig.show()

# %%
input_regression_temp_df["last2weeks"].value_counts()
# Out:
# 0    548
# 1    548
# Name: last2weeks, dtype: int64

# %%
weights_interaction_df.iloc[1]["model"].summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     district_percentage   R-squared:                       0.540
# Model:                             OLS   Adj. R-squared:                  0.526
# Method:                  Least Squares   F-statistic:                     39.00
# Date:                 Mon, 24 Jan 2022   Prob (F-statistic):          4.05e-155
# Time:                         13:22:10   Log-Likelihood:                -1108.2
# No. Observations:                 1096   AIC:                             2282.
# Df Residuals:                     1063   BIC:                             2447.
# Df Model:                           32
# Covariance Type:             nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                -4.4279      0.064    -68.786      0.000      -4.554      -4.302
# gender                                0.0283      0.066      0.425      0.671      -0.102       0.159
# rm                                   -0.0879      0.046     -1.922      0.055      -0.178       0.002
# n_candidates                         -0.2151      0.023     -9.269      0.000      -0.261      -0.170
# 1                                     0.8405      0.065     12.875      0.000       0.712       0.969
# 2                                     0.5459      0.072      7.568      0.000       0.404       0.687
# 3                                     0.3315      0.073      4.515      0.000       0.187       0.476
# 4                                     0.0412      0.076      0.539      0.590      -0.109       0.191
# CIUDADANOS                           -0.1192      0.242     -0.492      0.623      -0.595       0.356
# COMUNES                              -0.0694      0.130     -0.533      0.594      -0.325       0.186
# CONVER.                               0.5781      0.139      4.166      0.000       0.306       0.850
# EVOPOLI                               0.3046      0.108      2.822      0.005       0.093       0.516
# FREVS                                -0.1391      0.122     -1.141      0.254      -0.378       0.100
# IGUALDAD                             -0.2282      0.148     -1.540      0.124      -0.519       0.063
# PCC                                  -0.3299      0.280     -1.180      0.238      -0.879       0.219
# PCCH                                  0.3700      0.111      3.331      0.001       0.152       0.588
# PDC                                   0.1189      0.103      1.152      0.250      -0.084       0.321
# PEV                                  -0.3821      0.104     -3.680      0.000      -0.586      -0.178
# PH                                   -0.3226      0.284     -1.134      0.257      -0.881       0.236
# PL                                    0.0134      0.149      0.090      0.928      -0.278       0.305
# PNC                                9.643e-16   1.22e-16      7.911      0.000    7.25e-16     1.2e-15
# PPD                                   0.2778      0.128      2.169      0.030       0.027       0.529
# PR                                   -0.2520      0.185     -1.363      0.173      -0.615       0.111
# PRO                                  -0.6011      0.184     -3.268      0.001      -0.962      -0.240
# PS                                    0.3717      0.100      3.724      0.000       0.176       0.568
# PTR                                  -1.3646      0.125    -10.943      0.000      -1.609      -1.120
# RD                                    0.2705      0.107      2.535      0.011       0.061       0.480
# REPUBL.                              -0.0132      0.201     -0.065      0.948      -0.408       0.381
# RN                                    0.5202      0.091      5.719      0.000       0.342       0.699
# UDI                                   0.4817      0.102      4.726      0.000       0.282       0.682
# UPA                                  -1.8626      0.242     -7.712      0.000      -2.337      -1.389
# last2weeks                         1.223e-15      0.041      3e-14      1.000      -0.080       0.080
# retweet_count__logdnpt                0.2986      0.031      9.704      0.000       0.238       0.359
# retweet_count__logdnpt*last2weeks  1.263e-15      0.041    3.1e-14      1.000      -0.080       0.080
# ==============================================================================
# Omnibus:                       12.127   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               12.521
# Skew:                           0.225   Prob(JB):                      0.00191
# Kurtosis:                       3.269   Cond. No.                     1.41e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.09e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
reg_result_df["interaction"]
# Out:
# 0     last2weeks
# 1     last2weeks
# 2     last2weeks
# 3     last2weeks
# 4     last2weeks
# 5     last2weeks
# 6     last2weeks
# 7     last2weeks
# 8     last2weeks
# 9     last2weeks
# 10    last2weeks
# 11    last2weeks
# 12    last2weeks
# 13    last2weeks
# 14    last2weeks
# 15    last2weeks
# 16    last2weeks
# 17    last2weeks
# 18    last2weeks
# 19    last2weeks
# Name: interaction, dtype: object

# %% [markdown]
# ## Political Pagerank

# %% [markdown]
# ### Correlation

# %% [markdown]
# ### Regression
